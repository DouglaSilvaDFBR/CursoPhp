# %% [markdown]
# <a href="https://colab.research.google.com/github/DouglaSilvaDFBR/CursoPhp/blob/master/Rede_neural_para_converter_celsius_para_fahrenheit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
temperature_df = pd.read_csv("/content/Celsius-to-Fahrenheit.csv")
temperature_df.reset_index(drop= True, inplace= True)

# %%
temperature_df
# Out:
#     Celsius  Fahrenheit
# 0       -50       -58.0
# 1       -40       -40.0
# 2       -30       -22.0
# 3       -20        -4.0
# 4       -10        14.0
# 5        -9        15.8
# 6        -8        17.6
# 7        -7        19.4
# 8        -6        21.2
# 9        -5        23.0
# 10       -4        24.8
# 11       -3        26.6
# 12       -2        28.4
# 13       -1        30.2
# 14        0        32.0
# 15        1        33.8
# 16        2        35.6
# 17        3        37.4
# 18        4        39.2
# 19        5        41.0
# 20        6        42.8
# 21        7        44.6
# 22        8        46.4
# 23        9        48.2
# 24       10        50.0
# 25       20        68.0
# 26       30        86.0
# 27       40       104.0
# 28       50       122.0
# 29       60       140.0

# %%
temperature_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Celsius     30 non-null     int64
#  1   Fahrenheit  30 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 608.0 bytes

# %%
sns.scatterplot(temperature_df['Celsius'], temperature_df['Fahrenheit'])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
x_train = temperature_df['Celsius']
y_train = temperature_df['Fahrenheit']

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(units =1, input_shape = ([1])))
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_1 (Dense)             (None, 1)                 2
#
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(0.1), loss = 'mean_squared_error')

# %%
epochs_hits = model.fit(x_train, y_train, epochs= 500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 289ms/step - loss: 3.3703e-10
# Epoch 2/500
# 1/1 [==============================] - 0s 8ms/step - loss: 3.8683
# Epoch 3/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0814
# Epoch 4/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.4604
# Epoch 5/500
# 1/1 [==============================] - 0s 8ms/step - loss: 2.4675
# Epoch 6/500
# 1/1 [==============================] - 0s 6ms/step - loss: 1.2861
# Epoch 7/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1173
# Epoch 8/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2239
# Epoch 9/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.0229
# Epoch 10/500
# 1/1 [==============================] - 0s 7ms/step - loss: 1.2548
# Epoch 11/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7290
# Epoch 12/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.1285
# ...

# %%
epochs_hits.history.keys()
plt.plot(epochs_hits.history['loss'])

# %%
temp_c = 0
temp_f = model.predict([temp_c])
temp_f
print(temp_f)
# Out:
# 1/1 [==============================] - 0s 37ms/step
# [[32.]]
